# %%
from ingest import load_faq_data, build_index
from rag_helper import RAG
from openai import OpenAI
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 from ingest import load_faq_data, build_index
# ----> 2 from rag_helper import RAG
#       3 from openai import OpenAI
#
# File /workspaces/zoomcamp-llm-2026-code/rag_helper.py:11
#       1 INSTRUCTIONS = """
#       2 Your task is to answer questions from the course participants
#       3 based on the provided context.
#    (...)      7 respond with "I don't know."
#       8 """
#      10 USER_PROMPT_TEMPLATE = f"""
# ---> 11 QUESTION: {question}
#      12
#      13 CONTEXT:
#      14 {context}
#      15 """.strip()
#      17 class RAG:
#      18     def __init__(self, index, llm_client,
#      19         instructions=INSTRUCTIONS,
#      20         prompt_template=PROMPT_TEMPLATE,
#      21         course="llm-zoomcamp",
#      22         model="gpt-5.4-mini"):
#
# NameError: name 'question' is not defined

# %%
documents = load_faq_data()
index = build_index(documents)

openai_client = OpenAI()

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)

answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)

# %%
from rag_helper import RAG

RAG.search('docker')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from rag_helper import RAG
#       2
#       3 RAG.search('docker')
#
# File /workspaces/zoomcamp-llm-2026-code/rag_helper.py:12
#       1 INSTRUCTIONS = """
#       2 Your task is to answer questions from the course participants
#       3 based on the provided context.
#    (...)      7 respond with "I don't know."
#       8 """
#      10 USER_PROMPT_TEMPLATE = f"""
#      11 Question:
# ---> 12 {question}
#      13
#      14 Context:
#      15 {context}
#      16 """
#      18 class RAG:
#      19     def __init__(self, index):
#
# NameError: name 'question' is not defined
